# %%
import pandas as pd

# 1. CSV 불러오기
file_path = r"D:\Project\달서구음식점지도\daegu_food_all_gu_geocoded.csv"
data = pd.read_csv(file_path, encoding="utf-8-sig")  # cp949 쓰고 있으면 enc만 바꿔줘도 됨

# 2. 필요한 열만 선택
cols = ["BZ_NM", "GU", "SEAT_CNT", "PKPL"]  # 가게 이름/구 까지 같이 보면 편해서 넣었어
subset = data[cols]

# %%
subset
